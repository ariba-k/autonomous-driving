# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import files
uploaded = files.upload() # then browse, select the files. It's then uploaded
# choose Bikesgray.jpg and # choose plot_conf.py
# Out:
#      <input type="file" id="files-6e50c1f5-d054-48ba-b4cc-beb770514a97" name="files[]" multiple disabled />
#      <output id="result-6e50c1f5-d054-48ba-b4cc-beb770514a97">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Bikesgray.jpg to Bikesgray (1).jpg

# %%
# %run ~/plot_conf.py
plt_style('w')

# %%
imgB = np.array(Image.open('/content/Bikesgray.jpg'))

# %%
print(imgB.shape)
print(imgB)

imgB_Cropped = imgB[100:500, 330:600]
# Out:
# (480, 640)
# [[78 83 77 ... 65 67 68]
#  [79 82 77 ... 70 67 62]
#  [84 82 79 ... 73 72 66]
#  ...
#  [ 5  4 31 ...  8  9  8]
#  [ 4  8 26 ...  8  8 10]
#  [ 5  4  8 ... 10  7 11]]

# %%
plt.imshow(img_Intensity, cmap='PuBuGn_r')
