# %%
# http://pytorch.org/
from os import path
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
accelerator = 'cu90' if path.exists('/opt/bin/nvidia-smi') else 'cpu'
# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.0-{platform}-linux_x86_64.whl torchvision
import torch

# %%
import torch.nn.functional as F #import pytorch function module

# %%
input = torch.tensor([1.0,35.0,67.0])

# %%
w1 = torch.tensor([[0.2,-0.4],[-0.1,0.2],[0.1,-0.1]])
w2 = torch.tensor([[-3.0, 0.26],[1.0, 0.1],[-1.0,0.0]])

# %%
#MultiLayerPerceptron
a = F.relu(input @ w1)
b = torch.tensor([1,3.4000, 0.0000])
c = F.relu(b @ w2)
print(c)
#error1 = 1 - c[0]
#error2 = 0 - c[1]
#print(error1,error2)
# Out:
# tensor([ 0.4000,  0.6000])
