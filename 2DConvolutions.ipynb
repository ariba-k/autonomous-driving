# %%
from scipy import signal
from scipy import misc
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import files
uploaded = files.upload() # then browse, select the files. It's then uploaded
# choose Bikesgray.jpg and # choose plot_conf.py
# Out:
#      <input type="file" id="files-fb960a48-6f75-4d0b-9a3d-54434aa79d96" name="files[]" multiple disabled />
#      <output id="result-fb960a48-6f75-4d0b-9a3d-54434aa79d96">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Bikesgray.jpg to Bikesgray (1).jpg

# %%
# %run ~/plot_conf.py
plt_style('w')
# Out:
# ERROR:root:File `'/content/plot_conf.py'` not found.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-77becfd2d2d5> in <module>()
#       1 get_ipython().magic('run ~/plot_conf.py')
# ----> 2 plt_style('w')
#
# NameError: name 'plt_style' is not defined

# %%
img = np.array(Image.open('/content/Bikesgray.jpg'))

# %%
plt.imshow(img, cmap='gray')

# %% [markdown]
# # Convolutions with special kernels

# %%
I = np.array([[0,0,0],[0,1,0],[0,0,0]])
img_I = signal.convolve2d(img, I, mode='valid')
plt.subplot(1,2,1)
plt.imshow(img, cmap='gray')
plt.title("original image")
plt.subplot(1,2,2)
plt.imshow(img_I, cmap='gray')
plt.title("image after convolution")
# Out:
# Text(0.5,1,'image after convolution')

# %%
K1 = np.array([[1,0,-1],[2,0,-2],[1,0,-1]])
img_K1 = signal.convolve2d(img, K1, mode='valid')
plt.subplot(1,2,1)
plt.imshow(img, cmap='gray')
plt.title("original image")
plt.subplot(1,2,2)
plt.imshow(img_K1, cmap='gray')
plt.title("image after convolution")
# Out:
# Text(0.5,1,'image after convolution')

# %%
K2 = np.array([[1,2,1],[0,0,0],[-1,-2,-1]])
img_K2 = signal.convolve2d(img, K2, mode='valid')
plt.subplot(1,2,1)
plt.imshow(img, cmap='gray')
plt.title("original image")
plt.subplot(1,2,2)
plt.imshow(img_K2, cmap='gray')
plt.title("image after convolution")
# Out:
# Text(0.5,1,'image after convolution')

# %%
K3 = np.array([[1/16,2/16,1/16],[2/16,6/16,2/16],[1/16,2/16,1/16]])
img_K3 = signal.convolve2d(img, K3, mode='valid')
plt.subplot(1,2,1)
plt.imshow(img, cmap='gray')
plt.title("original image")
plt.subplot(1,2,2)
plt.imshow(img_K3, cmap='gray')
plt.title("image after convolution")
# Out:
# Text(0.5,1,'image after convolution')

# %%
diff = img_I - img_K3
plt.imshow(diff, cmap='gray')
plt.title("Difference")
# Out:
# Text(0.5,1,'Difference')
